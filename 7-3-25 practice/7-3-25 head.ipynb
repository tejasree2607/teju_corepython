# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("headbrain.csv")

# %%
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
x_df=df['Head Size(cm^3)']
y_df=df['Brain Weight(grams)']

# %%
x_mean=np.mean(x_df)
y_mean=np.mean(y_df)
m=np.sum((x_df-x_mean)*(y_df-y_mean))/np.sum((x_df-x_mean)**2)
c=y_mean-(m*x_mean)
print(f'The equation for the dataset is y={m:.2f}x+{c:.2f}')
# Out:
# The equation for the dataset is y=0.26x+325.57

# %%
pred=x_df*m+c

# %%
#r square
ssr=np.sum((pred-y_mean)**2)
sst=np.sum((y_df-y_mean)**2)
rsq=1-(ssr/sst)
print(f"{rsq:.2f}")
# Out:
# 0.36

# %%
plt.figure(figsize=(10,8))
plt.scatter(x_df,y_df,color='blue' , label='Actual data')
plt.scatter(x_df,pred,color='orange' , label='Predicted data')
plt.plot(x_df,pred, color='green',label='Best fit line')
plt.legend()
plt.xlabel("Head Size")
plt.ylabel("Brain Weight")
plt.title("Simple Linear Regression")
plt.show()
